# %% [markdown]
# # Install feast-teradata

# %% [markdown]
# Detailed information about feast-teradata package available on: https://pypi.org/project/feast-teradata/

# %% [markdown]
# ![Feast](images/feast-teradata_pypi.png)

# %% [markdown]
# ## Overview
# The feast-teradata library adds support for Teradata as
# * OfflineStore
# * OnlineStore
#
# Additional, using Teradata as the registry (catalog) is already supported via the registry_type: sql and included in our examples. This means that everything is located in Teradata. However, depending on the requirements, installation, etc, this can be mixed and matched with other systems as appropriate.
#
# ## Getting Started
# To get started, install the feast-teradata library

# %%
# !pip install feast-teradata
# Out:
# Collecting feast-teradata
#   Downloading feast_teradata-1.0.3-py3-none-any.whl (27 kB)
# Collecting teradataml>=17.0.0.4
#   Downloading teradataml-17.20.0.1-py3-none-any.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 391 kB/s eta 0:00:01
# Collecting feast==0.26.0
#   Downloading feast-0.26.0-cp39-cp39-macosx_10_15_x86_64.whl (32.2 MB)
#      |████████████████████████████████| 32.2 MB 796 kB/s eta 0:00:01
# Collecting numpy<3,>=1.22
#   Downloading numpy-1.24.2-cp39-cp39-macosx_10_9_x86_64.whl (19.8 MB)
#      |████████████████████████████████| 19.8 MB 629 kB/s eta 0:00:01    |██████████▍                     | 6.4 MB 269 kB/s eta 0:00:50
# Collecting mmh3
#   Downloading mmh3-3.0.0-cp39-cp39-macosx_10_9_x86_64.whl (12 kB)
# Requirement already satisfied: Jinja2<4,>=2 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from feast==0.26.0->feast-teradata) (2.11.3)
# Requirement already satisfied: toml<1,>=0.10.0 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from feast==0.26.0->feast-teradata) (0.10.2)
# Collecting grpcio-reflection<2,>=1.47.0
#   Downloading grpcio_reflection-1.51.1-py3-none-any.whl (11 kB)
# Collecting pandavro==1.5.*
#   Using cached pandavro-1.5.2.tar.gz (3.8 kB)
# Requirement already satisfied: tabulate<1,>=0.8.0 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from feast==0.26.0->feast-teradata) (0.8.9)
# Requirement already satisfied: google-api-core<3,>=1.23.0 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from feast==0.26.0->feast-teradata) (1.25.1)
# Collecting uvicorn[standard]<1,>=0.14.0
#   Downloading uvicorn-0.20.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 465 kB/s eta 0:00:01
# Requirement already satisfied: tenacity<9,>=7 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from feast==0.26.0->feast-teradata) (8.0.1)
# Requirement already satisfied: protobuf<5,>3 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from feast==0.26.0->feast-teradata) (3.19.1)
# Collecting pydantic<2,>=1
#   Downloading pydantic-1.10.4-cp39-cp39-macosx_10_9_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 894 kB/s eta 0:00:01
# Collecting dask<2022.02.0,>=2021.*
#   Downloading dask-2022.1.1-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 729 kB/s eta 0:00:01
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.* in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from feast==0.26.0->feast-teradata) (1.53.0)
# Collecting pyarrow<9,>=4
#   Downloading pyarrow-8.0.0-cp39-cp39-macosx_10_13_x86_64.whl (22.4 MB)
#      |████████████████████████████████| 22.4 MB 605 kB/s eta 0:00:01
# Collecting grpcio<2,>=1.47.0
#   Downloading grpcio-1.51.1-cp39-cp39-macosx_10_10_x86_64.whl (4.6 MB)
#      |████████████████████████████████| 4.6 MB 457 kB/s eta 0:00:01
# Collecting dill==0.3.*
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      |████████████████████████████████| 110 kB 425 kB/s eta 0:00:01
# Collecting proto-plus<2,>=1.20.0
#   Downloading proto_plus-1.22.2-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 497 kB/s eta 0:00:01
# Requirement already satisfied: click<9.0.0,>=7.0.0 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from feast==0.26.0->feast-teradata) (8.0.4)
# Requirement already satisfied: tqdm<5,>=4 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from feast==0.26.0->feast-teradata) (4.64.0)
# Requirement already satisfied: SQLAlchemy[mypy]<2,>1 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from feast==0.26.0->feast-teradata) (1.4.32)
# Requirement already satisfied: colorama<1,>=0.3.9 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from feast==0.26.0->feast-teradata) (0.4.4)
# Requirement already satisfied: jsonschema in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from feast==0.26.0->feast-teradata) (4.4.0)
# Collecting fastapi<1,>=0.68.0
#   Downloading fastapi-0.90.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 559 kB/s eta 0:00:01
# Collecting pygments<3,>=2.12.0
#   Downloading Pygments-2.14.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 391 kB/s eta 0:00:01
# Requirement already satisfied: PyYAML<7,>=5.4.* in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from feast==0.26.0->feast-teradata) (6.0)
# Collecting pandas<2,>=1.4.3
#   Downloading pandas-1.5.3-cp39-cp39-macosx_10_9_x86_64.whl (12.0 MB)
#      |████████████████████████████████| 12.0 MB 492 kB/s eta 0:00:01
# Collecting bowler
#   Downloading bowler-0.9.0-py3-none-any.whl (36 kB)
# Collecting fastavro<2,>=1.1.0
#   Downloading fastavro-1.7.1.tar.gz (787 kB)
#      |████████████████████████████████| 787 kB 453 kB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting typeguard
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: six>=1.9 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from pandavro==1.5.*->feast==0.26.0->feast-teradata) (1.16.0)
# Requirement already satisfied: packaging>=20.0 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from dask<2022.02.0,>=2021.*->feast==0.26.0->feast-teradata) (21.3)
# Requirement already satisfied: cloudpickle>=1.1.1 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from dask<2022.02.0,>=2021.*->feast==0.26.0->feast-teradata) (2.0.0)
# Requirement already satisfied: toolz>=0.8.2 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from dask<2022.02.0,>=2021.*->feast==0.26.0->feast-teradata) (0.11.2)
# Requirement already satisfied: partd>=0.3.10 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from dask<2022.02.0,>=2021.*->feast==0.26.0->feast-teradata) (1.2.0)
# Requirement already satisfied: fsspec>=0.6.0 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from dask<2022.02.0,>=2021.*->feast==0.26.0->feast-teradata) (2022.2.0)
# Collecting starlette<=0.23.0,>=0.22.0
#   Downloading starlette-0.23.0-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 547 kB/s eta 0:00:01
# Requirement already satisfied: google-auth<2.0dev,>=1.21.1 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from google-api-core<3,>=1.23.0->feast==0.26.0->feast-teradata) (1.33.0)
# Requirement already satisfied: pytz in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from google-api-core<3,>=1.23.0->feast==0.26.0->feast-teradata) (2021.3)
# Requirement already satisfied: setuptools>=40.3.0 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from google-api-core<3,>=1.23.0->feast==0.26.0->feast-teradata) (61.2.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from google-api-core<3,>=1.23.0->feast==0.26.0->feast-teradata) (2.27.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<3,>=1.23.0->feast==0.26.0->feast-teradata) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<3,>=1.23.0->feast==0.26.0->feast-teradata) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<3,>=1.23.0->feast==0.26.0->feast-teradata) (4.2.2)
# Collecting protobuf<5,>3
#   Downloading protobuf-4.21.12-cp37-abi3-macosx_10_9_universal2.whl (486 kB)
#      |████████████████████████████████| 486 kB 515 kB/s eta 0:00:01
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from Jinja2<4,>=2->feast==0.26.0->feast-teradata) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->dask<2022.02.0,>=2021.*->feast==0.26.0->feast-teradata) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from pandas<2,>=1.4.3->feast==0.26.0->feast-teradata) (2.8.2)
# Requirement already satisfied: locket in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from partd>=0.3.10->dask<2022.02.0,>=2021.*->feast==0.26.0->feast-teradata) (0.2.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core<3,>=1.23.0->feast==0.26.0->feast-teradata) (0.4.8)
# Collecting typing-extensions>=4.2.0
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3,>=1.23.0->feast==0.26.0->feast-teradata) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3,>=1.23.0->feast==0.26.0->feast-teradata) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3,>=1.23.0->feast==0.26.0->feast-teradata) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3,>=1.23.0->feast==0.26.0->feast-teradata) (2021.10.8)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy[mypy]<2,>1->feast==0.26.0->feast-teradata) (1.1.1)
# Collecting mypy>=0.910
#   Downloading mypy-1.0.0-cp39-cp39-macosx_10_9_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 356 kB/s eta 0:00:01
# Collecting sqlalchemy2-stubs
#   Downloading sqlalchemy2_stubs-0.0.2a32-py3-none-any.whl (191 kB)
#      |████████████████████████████████| 191 kB 590 kB/s eta 0:00:01
# Requirement already satisfied: mypy-extensions>=0.4.3 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from mypy>=0.910->SQLAlchemy[mypy]<2,>1->feast==0.26.0->feast-teradata) (0.4.3)
# Requirement already satisfied: tomli>=1.1.0 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from mypy>=0.910->SQLAlchemy[mypy]<2,>1->feast==0.26.0->feast-teradata) (1.2.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from starlette<=0.23.0,>=0.22.0->fastapi<1,>=0.68.0->feast==0.26.0->feast-teradata) (3.5.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette<=0.23.0,>=0.22.0->fastapi<1,>=0.68.0->feast==0.26.0->feast-teradata) (1.2.0)
# Collecting teradatasql>=17.10.0.11
#   Downloading teradatasql-17.20.0.14-py3-none-any.whl (28.9 MB)
#      |████████████████████████████████| 28.9 MB 477 kB/s eta 0:00:01
# Requirement already satisfied: psutil in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from teradataml>=17.0.0.4->feast-teradata) (5.8.0)
# Collecting docker>=4.2.0
#   Downloading docker-6.0.1-py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 602 kB/s eta 0:00:01
# Collecting teradatasqlalchemy>=17.0.0.4
#   Downloading teradatasqlalchemy-17.0.0.4-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 803 kB/s eta 0:00:01
# Collecting requests<3.0.0dev,>=2.18.0
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 754 kB/s eta 0:00:01
# Collecting idna<4,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 854 kB/s eta 0:00:01
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3,>=1.23.0->feast==0.26.0->feast-teradata) (4.0.0)
# Collecting docker>=4.2.0
#   Downloading docker-6.0.0-py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 732 kB/s eta 0:00:01
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 789 kB/s eta 0:00:01
# Requirement already satisfied: websocket-client>=0.32.0 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from docker>=4.2.0->teradataml>=17.0.0.4->feast-teradata) (0.58.0)
# Collecting pycryptodome
#   Downloading pycryptodome-3.17-cp35-abi3-macosx_10_9_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 923 kB/s eta 0:00:01
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 873 kB/s eta 0:00:01
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0
#   Downloading uvloop-0.17.0-cp39-cp39-macosx_10_9_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 445 kB/s eta 0:00:01
# Collecting websockets>=10.4
#   Downloading websockets-10.4-cp39-cp39-macosx_10_9_x86_64.whl (97 kB)
#      |████████████████████████████████| 97 kB 583 kB/s eta 0:00:01
# Collecting httptools>=0.5.0
#   Downloading httptools-0.5.0-cp39-cp39-macosx_10_9_x86_64.whl (161 kB)
#      |████████████████████████████████| 161 kB 583 kB/s eta 0:00:01
# Collecting python-dotenv>=0.13
#   Downloading python_dotenv-0.21.1-py3-none-any.whl (19 kB)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-0.18.1-cp37-abi3-macosx_10_7_x86_64.whl (377 kB)
#      |████████████████████████████████| 377 kB 638 kB/s eta 0:00:01
# Collecting fissix
#   Downloading fissix-21.11.13-py3-none-any.whl (188 kB)
#      |████████████████████████████████| 188 kB 418 kB/s eta 0:00:01
# Collecting volatile
#   Downloading volatile-2.1.0.tar.gz (3.3 kB)
# Collecting moreorless>=0.2.0
#   Downloading moreorless-0.4.0-py2.py3-none-any.whl (9.3 kB)
# Requirement already satisfied: attrs in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from bowler->feast==0.26.0->feast-teradata) (21.4.0)
# Requirement already satisfied: appdirs in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from fissix->bowler->feast==0.26.0->feast-teradata) (1.4.4)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/dp250054/opt/anaconda3/lib/python3.9/site-packages (from jsonschema->feast==0.26.0->feast-teradata) (0.18.0)
# Building wheels for collected packages: pandavro, fastavro, volatile
#   Building wheel for pandavro (setup.py) ... done
#   Created wheel for pandavro: filename=pandavro-1.5.2-py3-none-any.whl size=2953 sha256=812bc792b5d5bf5b7e451de16e22b76c18879380abebe2f343cc0c381dd38799
#   Stored in directory: /Users/dp250054/Library/Caches/pip/wheels/bc/da/0d/f0467cb9bb00c50da43572b76fcab102402291783f5e2e09cb
#   Building wheel for fastavro (PEP 517) ... done
#   Created wheel for fastavro: filename=fastavro-1.7.1-cp39-cp39-macosx_10_9_x86_64.whl size=476572 sha256=e64a11aba4fa0d6b982978dd2b7910708ad1b972b0e0a16ea2027fd62058b7ee
#   Stored in directory: /Users/dp250054/Library/Caches/pip/wheels/98/65/c0/07fcd45bae91d3a125573facc5b524775fc5b18cda201647f8
#   Building wheel for volatile (setup.py) ... done
#   Created wheel for volatile: filename=volatile-2.1.0-py3-none-any.whl size=3468 sha256=e40aef6ba4178a7cbbdd104d7ea9a317f8f918a031b817504c631dc9e27cb790
#   Stored in directory: /Users/dp250054/Library/Caches/pip/wheels/0c/b1/b9/9b0cfdf9f8ac4da73948288509d06e0d4a8c4589746d9fa44c
# Successfully built pandavro fastavro volatile
# Installing collected packages: idna, typing-extensions, pycryptodome, protobuf, numpy, h11, websockets, watchfiles, volatile, uvloop, uvicorn, teradatasql, starlette, sqlalchemy2-stubs, requests, python-dotenv, pydantic, pandas, mypy, moreorless, httptools, grpcio, fissix, fastavro, typeguard, teradatasqlalchemy, pygments, pyarrow, proto-plus, pandavro, mmh3, grpcio-reflection, fastapi, docker, dill, dask, bowler, teradataml, feast, feast-teradata
#   Attempting uninstall: idna
#     Found existing installation: idna 3.3
#     Uninstalling idna-3.3:
#       Successfully uninstalled idna-3.3
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.1
#     Uninstalling protobuf-3.19.1:
#       Successfully uninstalled protobuf-3.19.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Uninstalling requests-2.27.1:
#       Successfully uninstalled requests-2.27.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.2
#     Uninstalling pandas-1.4.2:
#       Successfully uninstalled pandas-1.4.2
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.42.0
#     Uninstalling grpcio-1.42.0:
#       Successfully uninstalled grpcio-1.42.0
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.11.2
#     Uninstalling Pygments-2.11.2:
#       Successfully uninstalled Pygments-2.11.2
#   Attempting uninstall: dask
#     Found existing installation: dask 2022.2.1
#     Uninstalling dask-2022.2.1:
#       Successfully uninstalled dask-2022.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# daal4py 2021.5.0 requires daal==2021.4.0, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.2 requires ruamel-yaml, which is not installed.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.24.2 which is incompatible.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.24.2 which is incompatible.
# distributed 2022.2.1 requires dask==2022.02.1, but you have dask 2022.1.1 which is incompatible.
# Successfully installed bowler-0.9.0 dask-2022.1.1 dill-0.3.6 docker-5.0.3 fastapi-0.90.0 fastavro-1.7.1 feast-0.26.0 feast-teradata-1.0.3 fissix-21.11.13 grpcio-1.51.1 grpcio-reflection-1.51.1 h11-0.14.0 httptools-0.5.0 idna-2.10 mmh3-3.0.0 moreorless-0.4.0 mypy-1.0.0 numpy-1.24.2 pandas-1.5.3 pandavro-1.5.2 proto-plus-1.22.2 protobuf-4.21.12 pyarrow-8.0.0 pycryptodome-3.17 pydantic-1.10.4 pygments-2.14.0 python-dotenv-0.21.1 requests-2.25.1 sqlalchemy2-stubs-0.0.2a32 starlette-0.23.0 teradataml-17.20.0.1 teradatasql-17.20.0.14 teradatasqlalchemy-17.0.0.4 typeguard-2.13.3 typing-extensions-4.4.0 uvicorn-0.20.0 uvloop-0.17.0 volatile-2.1.0 watchfiles-0.18.1 websockets-10.4

# %% [markdown]
# **Note**: be careful with clash between jupyterlab and feast libraries and Anaconda dependencies
